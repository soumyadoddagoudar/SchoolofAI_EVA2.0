# %% [markdown]
# #Assignment6B
# Improve network accuracy- Trying out different types of convolution layers,  Idea is to understand Inception models, and keras Functional API
#
# References-
#
# Depthwise separable convolution - https://keras.io/layers/convolutional/ keras.layers.SeparableConv2D
#
#
# Functonal API- https://keras.io/getting-started/functional-api-guide/

# %% [markdown]
# ##Load libraries, data and prepare data to train model

# %%
#Import libraries

from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout,GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

from keras.regularizers import l2
from keras.layers import Input, SeparableConv2D, Conv1D, Conv2D
from keras.layers import Concatenate
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# Data set - CIFAR 10 It has 10 classes, Each image have size 32X32. Train data has 50k images and test has 10k images.

# %%
#Import data
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
print(train_features.shape)
print(test_features.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
#plot some train examples
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
#function to plot graph of training
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
#Accuracy function 
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
#Normalize data
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ##Implementing different types of convolution layers
# Steps defined for assignment are
# 1.	Normal Convolution
# 2.	Spatially Separable Convolution  (Conv2d(x, (3,1)) followed by Conv2D(x,(1,3))
# 3.	Depthwise Separable Convolution- keras.layers.SeparableConv2D
# 4.	Grouped Convolution (use 3x3, 5x5 only)
# 5.	Grouped Convolution (use 3x3 only, one with dilation = 1, and another with dilation = 2)
# 6.	You must use all of the 5 above at least once
# 7.	Train this new model for 50 epochs.
# 8.	Save File as Assignment 6B

# %% [markdown]
# ###Redefining Model

# %% [markdown]
# 1.   Input size is specified for model(32,32,3). Started model from normal convolution layer, then grouped conv of spatially separable and depthwise separable.
# 2.   concatenated result of above layers is fed to maxpool layer follwed by goruped conv of 3X3 and 5X5.
#
# 3.   Finally GlobalAveragePool is used followed by softmax.
#
# **Accuracy obtained is : 88.4%**

# %%
import keras
input_ = Input(shape = (32,32,3))

# Define the model

#normal convolutions
conv1 = Conv2D(48,(3,3),padding = 'same')(input_)
bn1 = BatchNormalization()(conv1)
relu1 = Activation('relu')(bn1)
do1 = Dropout(0.1)(relu1)

#spatially  separable
conv2 = Conv2D(64, (3,1), padding = 'same')(do1)
conv3 = Conv2D(64, (1,3), padding = 'same')(conv2)
bn2 = BatchNormalization()(conv3)
relu2 = Activation('relu')(bn2)
do2 = Dropout(0.05)(relu2)

#Depthwise separable
conv4 = SeparableConv2D(64,(3,3),padding = 'same')(do1)
bn4 = BatchNormalization()(conv4)
relu4 = Activation('relu')(bn4)
do4 = Dropout(0.05)(relu4)


#concat depth wise and spatially separable outputs
concat1 = Concatenate(axis = 3)([do2,do4])

mp1 = MaxPooling2D(2,2)(concat1)


#grouped convolution-3X3,5X5
conv5=Convolution2D(192,(3,3),padding='same')(mp1)
bn5=BatchNormalization()(conv5)
relu5=Activation('relu')(bn5)
do5=Dropout(0.1)(relu5)


conv5_=Convolution2D(192,(5,5),padding='same')(mp1)
bn5_=BatchNormalization()(conv5_)
relu5_=Activation('relu')(bn5_)
do5_=Dropout(0.1)(relu5_)

#Concat (3,3) and (5,5) convolutions.
concat2 = Concatenate(axis = 3)([do5,do5_])

mp2 = MaxPooling2D(2,2)(concat2)


#Grouped Convolution (use 3x3 only, one with dilation = 1, and another with dilation = 2)
conv6=Convolution2D(96,(3,3),padding='same',dilation_rate=1)(mp2)
bn6=BatchNormalization()(conv6)
relu6=Activation('relu')(bn6)
do6=Dropout(0.1)(relu6)

conv6_=Convolution2D(96,(3,3),padding='same',dilation_rate=2)(mp2)
bn6_=BatchNormalization()(conv6_)
relu6_=Activation('relu')(bn6_)
do6_=Dropout(0.1)(relu6_)

concat3= Concatenate(axis=3)([do6, do6_])


conv7 = Conv2D(48,(3,3),padding = 'same')(concat3)
bn7 = BatchNormalization()(conv7)
relu7 = Activation('relu')(bn7)
do7 = Dropout(0.1)(relu7)

conv8=Convolution2D(10, 1,padding='same')(do7)





gap1 = GlobalAveragePooling2D()(conv8)
softmax = Activation('softmax')(gap1)

model = keras.Model(inputs = input_, outputs = softmax)


                     
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
print(model.summary())
keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 48)   1344        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 48)   192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 48)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 48)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   9280        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   12352       conv2d_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 64)   3568        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           dropout_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 192)  221376      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 192)  614592      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 192)  768         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 384)  0           dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 384)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 96)     331872      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 96)     331872      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 96)     384         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 96)     384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 96)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 96)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 96)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 96)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 192)    0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 48)     82992       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 48)     192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 48)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 48)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 10)     490         dropout_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 10)           0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 1,612,938
# Trainable params: 1,611,338
# Non-trainable params: 1,600
# __________________________________________________________________________________________________
# None

# %%
gvhfrom keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

start=time.time()
train_datagen = ImageDataGenerator(featurewise_center = True, 
                                   featurewise_std_normalization = True,
                                   rotation_range = 10,
                                   zoom_range = 0.10,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1)
test_datagen = ImageDataGenerator(featurewise_center = True, featurewise_std_normalization = True)
train_datagen.fit(train_features)
test_datagen.fit(test_features)

train_data_iter = train_datagen.flow(train_features,train_labels, batch_size = 128)
test_data_iter =  test_datagen.flow(test_features,test_labels, batch_size = 10000)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

CKPT = ModelCheckpoint(filepath = 'best_model_6b.hdf5', monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)
model_info = model.fit_generator(train_data_iter,
                                 steps_per_epoch = 1000, nb_epoch = 50, 
                                 validation_data = test_data_iter.next(), verbose=1, callbacks = [CKPT])

end=time.time()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=1000, validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., epochs=50)`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# 1000/1000 [==============================] - 169s 169ms/step - loss: 1.0494 - acc: 0.6299 - val_loss: 1.1290 - val_acc: 0.6233
#
# Epoch 00001: val_acc improved from -inf to 0.62330, saving model to best_model_6b.hdf5
# Epoch 2/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.6492 - acc: 0.7747 - val_loss: 0.7953 - val_acc: 0.7289
#
# Epoch 00002: val_acc improved from 0.62330 to 0.72890, saving model to best_model_6b.hdf5
# Epoch 3/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.5048 - acc: 0.8243 - val_loss: 0.6513 - val_acc: 0.7776
#
# Epoch 00003: val_acc improved from 0.72890 to 0.77760, saving model to best_model_6b.hdf5
# Epoch 4/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.4137 - acc: 0.8556 - val_loss: 0.5162 - val_acc: 0.8260
#
# Epoch 00004: val_acc improved from 0.77760 to 0.82600, saving model to best_model_6b.hdf5
# Epoch 5/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.3391 - acc: 0.8815 - val_loss: 0.5936 - val_acc: 0.8060
#
# Epoch 00005: val_acc did not improve from 0.82600
# Epoch 6/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.2841 - acc: 0.9017 - val_loss: 0.7318 - val_acc: 0.7856
#
# Epoch 00006: val_acc did not improve from 0.82600
# Epoch 7/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.2347 - acc: 0.9175 - val_loss: 0.6435 - val_acc: 0.8071
#
# Epoch 00007: val_acc did not improve from 0.82600
# Epoch 8/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1979 - acc: 0.9312 - val_loss: 0.6446 - val_acc: 0.8131
#
# Epoch 00008: val_acc did not improve from 0.82600
# Epoch 9/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1707 - acc: 0.9398 - val_loss: 0.7558 - val_acc: 0.8179
#
# Epoch 00009: val_acc did not improve from 0.82600
# Epoch 10/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1428 - acc: 0.9501 - val_loss: 0.6650 - val_acc: 0.8248
#
# Epoch 00010: val_acc did not improve from 0.82600
# Epoch 11/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1282 - acc: 0.9549 - val_loss: 0.6953 - val_acc: 0.8303
#
# Epoch 00011: val_acc improved from 0.82600 to 0.83030, saving model to best_model_6b.hdf5
# Epoch 12/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1113 - acc: 0.9615 - val_loss: 0.5829 - val_acc: 0.8479
#
# Epoch 00012: val_acc improved from 0.83030 to 0.84790, saving model to best_model_6b.hdf5
# Epoch 13/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.1009 - acc: 0.9646 - val_loss: 0.6351 - val_acc: 0.8477
#
# Epoch 00013: val_acc did not improve from 0.84790
# Epoch 14/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0919 - acc: 0.9675 - val_loss: 0.5278 - val_acc: 0.8703
#
# Epoch 00014: val_acc improved from 0.84790 to 0.87030, saving model to best_model_6b.hdf5
# Epoch 15/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0866 - acc: 0.9702 - val_loss: 0.6620 - val_acc: 0.8473
#
# Epoch 00015: val_acc did not improve from 0.87030
# Epoch 16/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0807 - acc: 0.9718 - val_loss: 0.5215 - val_acc: 0.8660
#
# Epoch 00016: val_acc did not improve from 0.87030
# Epoch 17/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0727 - acc: 0.9748 - val_loss: 0.5380 - val_acc: 0.8702
#
# Epoch 00017: val_acc did not improve from 0.87030
# Epoch 18/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0703 - acc: 0.9753 - val_loss: 0.6393 - val_acc: 0.8559
#
# Epoch 00018: val_acc did not improve from 0.87030
# Epoch 19/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0662 - acc: 0.9770 - val_loss: 0.6134 - val_acc: 0.8582
#
# Epoch 00019: val_acc did not improve from 0.87030
# Epoch 20/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0615 - acc: 0.9790 - val_loss: 0.6221 - val_acc: 0.8589
#
# Epoch 00020: val_acc did not improve from 0.87030
# Epoch 21/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0575 - acc: 0.9801 - val_loss: 0.8549 - val_acc: 0.8257
#
# Epoch 00021: val_acc did not improve from 0.87030
# Epoch 22/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0541 - acc: 0.9813 - val_loss: 0.6953 - val_acc: 0.8539
#
# Epoch 00022: val_acc did not improve from 0.87030
# Epoch 23/50
# 1000/1000 [==============================] - 161s 161ms/step - loss: 0.0554 - acc: 0.9813 - val_loss: 0.6797 - val_acc: 0.8477
#
# Epoch 00023: val_acc did not improve from 0.87030
# Epoch 24/50
# 1000/1000 [==============================] - 163s 163ms/step - loss: 0.0497 - acc: 0.9830 - val_loss: 0.6114 - val_acc: 0.8664
#
# Epoch 00024: val_acc did not improve from 0.87030
# Epoch 25/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0498 - acc: 0.9824 - val_loss: 0.6698 - val_acc: 0.8643
#
# Epoch 00025: val_acc did not improve from 0.87030
# Epoch 26/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0476 - acc: 0.9834 - val_loss: 0.5266 - val_acc: 0.8817
#
# Epoch 00026: val_acc improved from 0.87030 to 0.88170, saving model to best_model_6b.hdf5
# Epoch 27/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0452 - acc: 0.9844 - val_loss: 0.5728 - val_acc: 0.8763
#
# Epoch 00027: val_acc did not improve from 0.88170
# Epoch 28/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0436 - acc: 0.9849 - val_loss: 0.5715 - val_acc: 0.8773
#
# Epoch 00028: val_acc did not improve from 0.88170
# Epoch 29/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0414 - acc: 0.9858 - val_loss: 0.6266 - val_acc: 0.8667
#
# Epoch 00029: val_acc did not improve from 0.88170
# Epoch 30/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0414 - acc: 0.9859 - val_loss: 0.6866 - val_acc: 0.8600
#
# Epoch 00030: val_acc did not improve from 0.88170
# Epoch 31/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0406 - acc: 0.9859 - val_loss: 0.5842 - val_acc: 0.8793
#
# Epoch 00031: val_acc did not improve from 0.88170
# Epoch 32/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0397 - acc: 0.9863 - val_loss: 0.6031 - val_acc: 0.8751
#
# Epoch 00032: val_acc did not improve from 0.88170
# Epoch 33/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0372 - acc: 0.9873 - val_loss: 0.6073 - val_acc: 0.8732
#
# Epoch 00033: val_acc did not improve from 0.88170
# Epoch 34/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0372 - acc: 0.9874 - val_loss: 0.6565 - val_acc: 0.8650
#
# Epoch 00034: val_acc did not improve from 0.88170
# Epoch 35/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0364 - acc: 0.9876 - val_loss: 0.6348 - val_acc: 0.8728
#
# Epoch 00035: val_acc did not improve from 0.88170
# Epoch 36/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0348 - acc: 0.9881 - val_loss: 0.6845 - val_acc: 0.8707
#
# Epoch 00036: val_acc did not improve from 0.88170
# Epoch 37/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0350 - acc: 0.9880 - val_loss: 0.6500 - val_acc: 0.8724
#
# Epoch 00037: val_acc did not improve from 0.88170
# Epoch 38/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0326 - acc: 0.9888 - val_loss: 0.6951 - val_acc: 0.8648
#
# Epoch 00038: val_acc did not improve from 0.88170
# Epoch 39/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0319 - acc: 0.9889 - val_loss: 0.5926 - val_acc: 0.8754
#
# Epoch 00039: val_acc did not improve from 0.88170
# Epoch 40/50
# 1000/1000 [==============================] - 163s 163ms/step - loss: 0.0321 - acc: 0.9889 - val_loss: 0.6469 - val_acc: 0.8726
#
# Epoch 00040: val_acc did not improve from 0.88170
# Epoch 41/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0287 - acc: 0.9901 - val_loss: 0.5973 - val_acc: 0.8773
#
# Epoch 00041: val_acc did not improve from 0.88170
# Epoch 42/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0310 - acc: 0.9891 - val_loss: 0.6650 - val_acc: 0.8708
#
# Epoch 00042: val_acc did not improve from 0.88170
# Epoch 43/50
# 1000/1000 [==============================] - 163s 163ms/step - loss: 0.0300 - acc: 0.9895 - val_loss: 0.5475 - val_acc: 0.8846
#
# Epoch 00043: val_acc improved from 0.88170 to 0.88460, saving model to best_model_6b.hdf5
# Epoch 44/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0287 - acc: 0.9902 - val_loss: 0.6817 - val_acc: 0.8677
#
# Epoch 00044: val_acc did not improve from 0.88460
# Epoch 45/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0285 - acc: 0.9900 - val_loss: 0.6616 - val_acc: 0.8753
#
# Epoch 00045: val_acc did not improve from 0.88460
# Epoch 46/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0263 - acc: 0.9911 - val_loss: 0.6148 - val_acc: 0.8800
#
# Epoch 00046: val_acc did not improve from 0.88460
# Epoch 47/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0271 - acc: 0.9907 - val_loss: 0.6424 - val_acc: 0.8742
#
# Epoch 00047: val_acc did not improve from 0.88460
# Epoch 48/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0283 - acc: 0.9902 - val_loss: 0.6054 - val_acc: 0.8827
#
# Epoch 00048: val_acc did not improve from 0.88460
# Epoch 49/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0249 - acc: 0.9914 - val_loss: 0.6577 - val_acc: 0.8747
#
# Epoch 00049: val_acc did not improve from 0.88460
# Epoch 50/50
# 1000/1000 [==============================] - 162s 162ms/step - loss: 0.0257 - acc: 0.9912 - val_loss: 0.7004 - val_acc: 0.8720
#
# Epoch 00050: val_acc did not improve from 0.88460

# %%
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# Out:
# Model took 8111.71 seconds to train

# %%
# compute test accuracy
model.load_weights('./best_model_6b.hdf5')
test_features, test_labels = test_data_iter.next()
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Accuracy on test data is: 88.46
