# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadoddagoudar/SchoolofAI_EVA2.0/blob/master/EVA_S1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D34D0E48>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7FA7D2848860>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D2848EB8>

# %% [markdown]
# # **Assignment 1A:**

# %% [markdown]
# # **Horizontal Edge Detector**

# %%
kernel=np.float32([[-1,-1,-1],[0,0,0],[1,1,1]])

dist=cv2.filter2D(image,-1,kernel)

cv2_imshow(dist)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F62EB8>

# %% [markdown]
# # **45 Degree Angle Detector (either)**

# %%
kernel = np.float32([[0,1,2],[-1,0,1],[-2,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F62A90>

# %%
kernel = np.float32([[0,-1,0],[1,0,1],[0,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F628D0>

# %% [markdown]
# # **Blur Kernel**

# %%
    blur = cv2.GaussianBlur(image,(15,15),0)
    cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F669B0>

# %%
smallBlur = np.ones((3, 3), dtype="float") * (1.0 / (7 * 7))
largeBlur = np.ones((21, 21), dtype="float") * (1.0 / (21 * 21))

# %%
dist_smallblur=cv2.filter2D(image,-1, smallBlur)
cv2_imshow(dist_smallblur)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F763C8>

# %%
dist_largeblur=cv2.filter2D(image,-1,largeBlur)
cv2_imshow(dist_largeblur)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F762E8>

# %% [markdown]
# # Sharpen Kernel

# %%
sharpen = np.array((
	[0, -1, 0],
	[-1, 5, -1],
	[0, -1, 0]), dtype="int")

dist_sharpen=cv2.filter2D(image,-1,sharpen)
cv2_imshow(dist_sharpen)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F66860>

# %%
Identity function (doesn't do anything)

# %% [markdown]
# # **Identity function (doesn't do anything)**

# %% [markdown]
# A trivial kernel is the ‘identity kernel’, i.e a 3 x 3 matrix  with zeros in every position except the middle (1,1). Applying this kernel to a window of the image will result in an unchanged pixel value.

# %%
kernel = np.float32([[0,0,0],[0,1,0],[0,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7FA7D0F662E8>
